# %% [markdown]
# ### Užduotis 1
#
# Dovydas Martinkus
# 3k. 2gr.
#
# Tema:\
# Pasirinktų prekių puslapio nagrinejimas. \
# Puslapis ikea.lt.

# %%
import requests
from bs4 import BeautifulSoup

import pandas as pd
import numpy as np
import os

import time
import re
from functools import partial

# %%
# getting the 'metapage' - this webpage has the links to all the item types
r_meta = requests.get("https://www.ikea.lt/en/products")
ikea = "https://www.ikea.lt" # this will be used to construct the required links in the future

# %%
soup_meta = BeautifulSoup(r_meta.text) # parsing the metapage

links_type = soup_meta.select(":not(.dropdown-item)[href*='products']") # all the links to the item types

# Filtering item types
regex_type = re.compile("ikea-verslui|kaledos|dovanu-korteles")
links_type = [ikea + i["href"] for i in links_type if not regex_type.search(i["href"])]

# %%
links_type[1:5]
# Out:
# ['https://www.ikea.lt/en/products/kitchen/enhet-system',
#  'https://www.ikea.lt/en/products/kitchen/knoxhult-system',
#  'https://www.ikea.lt/en/products/kitchen/sunnersta-kitchen',
#  'https://www.ikea.lt/en/products/kitchen/kitchen-appliances']

# %% [markdown]
# The goal is to create a row in a table like this for each item listed in the store:
#
# | title  | description | url | availability | metatype | type | subtype | packages | length | width | height | gross weight| price |
# | ----------- | ----------- | | | | | | | | | | | |
# | NEREBY  |  Vacuum hose holder... | http://www.ikea.lt/en/products/kitchen/... | instock| virtuve | system-knoxhult | kitchen-interior-organisers	| 1.0 | 23.0 | 12.0 | 3.0 | 0.19 | 6 |

# %%
# These attributes will appear as attributes of HTML tags in the parsed webpage
attributes_item_1 = ["og:title", "og:description", "og:url", "product:price:amount", "og:availability"] 

# These attributes will appear as table rows in the parsed webpage
attributes_item_2 =  ["Pakuotės: ","Ilgis: ","Plotis: ","Aukštis: ","Bendrasis svoris: "]

# %%
def scrap_items(links_type,skip=None):
    """
    Scrap items from the IKEA store and save them to disk.

    Parameters
    ----------
    links_type : list
        The list with the top-level links to scrap.
    skip : sequence
        Index positions of the links to skip. 
        Used to continue scrapping in case an error was thrown.

    Returns
    -------
    None
    """
    if skip is None:
        skip = []
    for num_type,link_type in enumerate(links_type):
            if (num_type is not None) and (num_type in skip): 
                continue
            print("Currently in item type ",num_type," ",link_type) # for convenience, to know what is currently being scrapped
            list_items = [] # list where the items of the same type will be stored
            try:
                r_type = requests.get(link_type,timeout=2) # getting the type webpage
            except requests.exceptions.Timeout:
                print("Timed out")
                continue
            soup_type = BeautifulSoup(r_type.text) # parsing the type webpage
            try:
                # largest number that appears in the page selection = number of pages
                total_pages_type = max([int(i["data-page"]) for i in soup_type.select("a.page-link[data-page]:not([aria-label])")])
            except ValueError:
                # website specific : no page selection = only a single page of items of that type exists
                total_pages_type = 1

            for num_page in range(1,total_pages_type+1):
                print("Currently in page",num_page) # again for convenience
                # constructing the link for a specific page of items of the same type
                link_type_page = link_type + "?page=" + str(num_page) 
                try:
                    r_type_page = requests.get(link_type_page,timeout=2) # getting the specified page of items of the same type
                except requests.exceptions.Timeout:
                    print("Timed out")
                    continue
                soup_type_page = BeautifulSoup(r_type_page.text)

                for item in soup_type_page.select("a.itemName"):
                    time.sleep(2) # to prevent getting thrown out for web scrapping
                    link_item = ikea + item["href"] # creating the link for the item webpage
                    try:
                        r_item = requests.get(link_item,timeout=2) # downloading the item webpage
                    except requests.exceptions.Timeout:
                        print("Timed out")
                        continue
                    soup_item = BeautifulSoup(r_item.text)
                    dict_item = dict() # dictionary to store the item attributes
                    # getting the attributes for the item from the meta tags:
                    for i in soup_item.find_all("meta",attrs={"property":attributes_item_1}):
                        dict_item[str(i["property"])] = str(i["content"])
                    # Extracting item type/subtype from the url: 
                    try:
                        for i,j in zip(["metatype","type","subtype"],dict_item["og:url"].split("/")[5:8]):
                            dict_item[i]= j
                    except KeyError:
                        print("Key error: this was caused because the url of item doesn't follow the usual structure")
                    # getting attributes from a table in the webpage:
                    for i in soup_item.find_all("td",text=attributes_item_2):
                        dict_item[str(i.string)]= str(i.next_sibling.string)
                    list_items.append(dict_item) # adding the item with it's attributes to the list of items of the same type
            # Saving all the items of a single type to disk
            df=pd.DataFrame(list_items)
            df.to_pickle("just_now/pickle"+str(num_type+1))

            
# Example: scrapping a very small type that only has two items
scrap_items([links_type[3]])
pd.read_pickle("just_now/pickled") # looks mostly as expected but still need to make a few changes
# Out:
# Currently in item type  0   https://www.ikea.lt/lt/products/virtuve/virtuvele-sunnersta
# Currently in page 1
#     og:title                                     og:description  \
# 0  SUNNERSTA  Su virtuvėle SUNNERSTA lengva įsirengti prakti...
# 1  SUNNERSTA  Su virtuvėle SUNNERSTA lengva įsirengti prakti...
#
#                                               og:url product:price:amount  \
# 0  http://www.ikea.lt/lt/products/virtuve/virtuve...                   95
# 1  http://www.ikea.lt/lt/products/virtuve/virtuve...                  129
#
#   og:availability metatype                 type            subtype Pakuotės:   \
# 0         instock  virtuve  virtuvele-sunnersta  atskiros-virtuves          1
# 1         instock  virtuve  virtuvele-sunnersta  atskiros-virtuves          1
#
#   Ilgis:  Plotis:  Aukštis:  Bendrasis svoris:
# 0  115 cm    62 cm     17 cm           16,35 kg
# 1  115 cm    62 cm     17 cm           16,35 kg

# %%
# creating the names for the saved files to be read in
names_pickle = ["pickles_en\\"  + p for p in os.listdir("pickles_en")]

# reading in and concatenating the files into a single DataFrame    
df = pd.concat(list(map(pd.read_pickle,names_pickle)),ignore_index=True)

# %%
# tidying the DataFrame

def my_rename(column_name):
    """
    Rename the columns using specific rules for the item table.
    
    Parameters
    ----------
    column_name : str
        Column name to convert.
        
    Returns
    -------
    str:
        Converted column name.

    """
    if "og:" in column_name:
        return str(column_name[3:].lower())
    elif column_name ==  "product:price:amount":
        return "price"
    else:
        return str(column_name.strip().strip(":").lower())
    
df = df.rename(columns=my_rename)

# moving the price column to the end for convenience
df.insert(len(df.columns)-1, 'price', df.pop('price'))


def my_numeric(column):
    """
    Convert the column to numeric after stripping it's values of 'cm' or 'kg'.
    
    Parameters
    ----------
    column : Series
        Column to convert to a numeric type.
        
    Returns
    -------
    Series:
        Column converted to a numeric type.
    """
    return pd.to_numeric(column.str.strip("cm").str.strip("kg").str.replace(",","."),errors="coerce")

# applying the function to every column that should be numeric
df.iloc[:,7:] = df.iloc[:,7:].apply(my_numeric)

df = df[df["description"]!=""].reset_index(drop=True)

# %%
df # 20000+ items in the DataFrame
# Out:
#                        title  \
# 0                   FÖRENKLA
# 1                    PIVRING
# 2                    RENSARE
# 3                   STARTTID
# 4                   STARTTID
# ...                      ...
# 21581               KNARDRUP
# 21582              AVSKILDRA
# 21583               LANGSTED
# 21584              SVÄRDBORG
# 21585  PERSISK KELIM GASHGAI
#
#                                              description  \
# 0      Two inner pockets for things you want to keep ...
# 1      The backpack stays firmly in place since the s...
# 2      This clothes bag has 2 compartments – one with...
# 3      There’s a separate compartment in the back tha...
# 4      Inside the backpack there are 2 large compartm...
# ...                                                  ...
# 21581  A timeless design with a sheen effect.\nThe so...
# 21582  The beauty is in the uniqueness - this rug is ...
# 21583  The cut edges makes it easy to join several ru...
# 21584  The beauty is in the uniqueness - this rug is ...
# 21585  The rug has the same pattern on both sides, so...
#
#                                                      url  availability  \
# 0      http://www.ikea.lt/en/products/hallway/bags-an...       instock
# 1      http://www.ikea.lt/en/products/hallway/bags-an...       instock
# 2      http://www.ikea.lt/en/products/hallway/bags-an...       instock
# 3      http://www.ikea.lt/en/products/hallway/bags-an...       instock
# 4      http://www.ikea.lt/en/products/hallway/bags-an...       instock
# ...                                                  ...           ...
# 21581  http://www.ikea.lt/en/products/living-room/hom...  out of stock
# 21582  http://www.ikea.lt/en/products/living-room/hom...  out of stock
# 21583  http://www.ikea.lt/en/products/living-room/hom...  out of stock
# 21584  http://www.ikea.lt/en/products/living-room/hom...  out of stock
# 21585  http://www.ikea.lt/en/products/living-room/hom...  out of stock
#
#           metatype                         type                      subtype  \
# 0          hallway  bags-and-travel-accessories  bags-and-travel-accessories
# 1          hallway  bags-and-travel-accessories  bags-and-travel-accessories
# 2          hallway  bags-and-travel-accessories  bags-and-travel-accessories
# 3          hallway  bags-and-travel-accessories  bags-and-travel-accessories
# 4          hallway  bags-and-travel-accessories  bags-and-travel-accessories
# ...            ...                          ...                          ...
# 21581  living-room         home-furnishing-rugs                         rugs
# 21582  living-room         home-furnishing-rugs                         rugs
# 21583  living-room         home-furnishing-rugs       small-rugs-and-runners
# 21584  living-room         home-furnishing-rugs                         rugs
# 21585  living-room         home-furnishing-rugs                oriental-rugs
#
#        packages  length  width  height  weight gross   price
# 0           1.0    80.0   38.0    20.0          3.20   69.99
# 1           1.0    37.0   27.0     2.0          0.12    1.99
# 2           1.0    20.0   15.0     2.0          0.08    2.99
# 3           1.0    42.0   37.0     3.0          0.40   19.99
# 4           1.0    57.0   31.0    16.0          1.50   19.99
# ...         ...     ...    ...     ...           ...     ...
# 21581       1.0   202.0    NaN     NaN         10.85  179.00
# 21582       1.0   174.0    NaN     NaN         18.30  279.00
# 21583       1.0    80.0   80.0    15.0          1.40    9.99
# 21584       1.0   138.0    NaN     NaN         11.54  199.00
# 21585       1.0   300.0   80.0     1.0          4.40  229.00
#
# [21586 rows x 13 columns]

# %%
import tensorflow as tf

import tensorflow_hub as hub

from sklearn.metrics.pairwise import cosine_similarity as cosine

import numpy as np

# Universal sentence encoder will be used to create emebeddings of the item descriptions
module_url = "https://tfhub.dev/google/universal-sentence-encoder/4"
model = hub.load(module_url)


def create_embeddings(df,model):
    embeddings=df.iloc[:,1].to_numpy().astype("str")
    embeddings=model(tf.convert_to_tensor(embeddings))
    return embeddings

embeddings = create_embeddings(df,model).numpy()

# %%
# Savingthe embeddings to disk
import numpy as np
np.save("embeddings.npy",embeddings)

# %%
def most_similar(row,df,embeddings = None,limit=5,unique = True,
                 threshold = 0,categorical_weight = 1,
                 numeric_weight= 1,reverse = False, append = False):
    
    """Find most similar items.
    
    Compares the sentence embeddings for the descriptions of the items
    using cosine similarity and returns the most similar items.

    Parameters
    ----------
    row : int or named Series or DataFrame
        The row to find the most similar items for.
        If given a DataFrame the first row will be selected.
        If given an int the df will be indexed using it as a label.
    df : DataFrame
        DataFrame to find the most similar items in.
    embeddings: array_like, Default None
        Sentence embeddings to compare the description of a given row against using cosine similarity.
    limit: int, Default 5
        The number of items to return.
    unique: boolean, Default True
        Whether to return only one item most with the same description. 
    threshold: float, Default 0
        If larger than 0, filter the DataFrame to only include items with higher similarity score for other attributes
        than the threshold. If given a negative number will take it's absolute value and filter 
        to include items with lower similarity score for other attributes.
    categorical_weight, numeric_weight: float, Default 1
        Calculation parameters to give categorical or numeric attributes more weight
        when chekcing the similarity of attributes other than description.
    reverse: boolean, Default False
        If true returns the least similar items.
    append: boolean, Default False
        Whether to add the cosine similariy as a column of the returned DataFrame

    Returns
    -------
    DataFrame:
        DataFrame with the items most similar to the given row.
    Series:
        Series with the similarity scores for each row of the returned DataFrame.
    """
    
    if embeddings is None or len(embeddings) != len(df):
        raise ValueError("Compatible sentence embeddings not found!\nYou probably deleted rows from the\
        data frame since the last time you ran this\nCreate the embeddings again")
    
    if isinstance(row,int):
        row = df.loc[row,:]
    elif isinstance(row,pd.DataFrame):
        row = row.iloc[0,:]


    relevant = np.ones(len(df)).astype("bool")
    if threshold != 0:
        col_categorical =  [0,*list(range(2,8))]
        col_numeric = range(8,13)

        comp_categorical = row[col_categorical] == df.iloc[:,col_categorical]
        sim_1 = comp_categorical.sum(axis=1) * categorical_weight

        max_value = df.iloc[:,col_numeric].max()
        min_value = df.iloc[:,col_numeric].min()
        comp_numeric = 1-(abs(row[col_numeric] - df.iloc[:,col_numeric]) / (max_value - min_value))
        sim_2 = comp_numeric.sum(axis=1) * numeric_weight

        relevant = (sim_1 + sim_2).sort_values(ascending=False) / \
            ((len(col_categorical)*categorical_weight)+(len(col_numeric)*numeric_weight))
        if threshold > 0:
            relevant = relevant > threshold
        else:
            relevant = relevant < abs(threshold)
            
            
        
    results=cosine(embeddings[row.name].reshape(1,-1),embeddings)[0]
    results=pd.Series(results,index=df.index)[relevant]
    results=results[df["description"]!=row[1]]
    
    if unique:
        results=results[~df["description"].duplicated()]
        
    results=results.sort_values(ascending=reverse).head(limit)
    results_df = df.loc[results.index]
                        
    if append:
        results_df = results_df.copy()
        results_df["similarity"] = results
    return results_df, results

# %%
# Getting items with the most similar descriptions
# High chance of getting multiple items with the same description
res,_ = most_similar(1,df,embeddings,limit=7,unique=False,append=True)
res
# Out:
#        title                                        description  \
# 24  STARTTID  The backpack has a handy outer compartment whe...
# 22  STARTTID  The backpack has a handy outer compartment whe...
# 3   STARTTID  There’s a separate compartment in the back tha...
# 13  STARTTID  The backpack has a handy outer compartment whe...
# 23  DRÖMSÄCK  The fabric is made of recycled polyester. Usin...
# 12  DRÖMSÄCK  The fabric is made of recycled polyester. Usin...
# 5   VÄRLDENS  The bag is comfortable to carry and sits firml...
#
#                                                   url availability metatype  \
# 24  http://www.ikea.lt/en/products/hallway/bags-an...      instock  hallway
# 22  http://www.ikea.lt/en/products/hallway/bags-an...      instock  hallway
# 3   http://www.ikea.lt/en/products/hallway/bags-an...      instock  hallway
# 13  http://www.ikea.lt/en/products/hallway/bags-an...      instock  hallway
# 23  http://www.ikea.lt/en/products/hallway/bags-an...      instock  hallway
# 12  http://www.ikea.lt/en/products/hallway/bags-an...      instock  hallway
# 5   http://www.ikea.lt/en/products/hallway/bags-an...      instock  hallway
#
#                            type                      subtype  packages  \
# 24  bags-and-travel-accessories  bags-and-travel-accessories       1.0
# 22  bags-and-travel-accessories  bags-and-travel-accessories       1.0
# 3   bags-and-travel-accessories  bags-and-travel-accessories       1.0
# 13  bags-and-travel-accessories  bags-and-travel-accessories       1.0
# 23  bags-and-travel-accessories  bags-and-travel-accessories       1.0
# 12  bags-and-travel-accessories  bags-and-travel-accessories       1.0
# 5   bags-and-travel-accessories  bags-and-travel-accessories       1.0
#
#     length  width  height  weight gross  price  similarity
# 24    38.0   33.0     3.0          0.29   6.99    0.808151
# 22    38.0   33.0     3.0          0.29   6.99    0.808151
# 3     42.0   37.0     3.0          0.40  19.99    0.793498
# 13    38.0   33.0     3.0          0.29   9.99    0.785619
# 23    29.0   20.0     5.0          0.14   9.99    0.767641
# 12    48.0   41.0     2.0          0.68  29.99    0.743566
# 5     25.0   20.0     3.0          0.14   7.99    0.726541

# %%
# Getting only one item with the same description
res,_ = most_similar(1,df,embeddings,limit=7,unique=True,append=True)
res
# Out:
#              title                                        description  \
# 13056       MYLLRA  The front of the changing table can be removed...
# 13062       MYLLRA  You can easily reach diapers and clothes since...
# 13048       MYLLRA  If you want to create a complete children's ro...
# 13092       MYLLRA  One cot side can be removed when the child is ...
# 5069   VINTER 2020  Made of a durable material which does not brea...
# 5209   VINTER 2020  Easy to hang up, as hooks are included. \nMade...
# 5040   VINTER 2020  Easy to hang up, as ribbons are included. \nWi...
#
#                                                      url availability  \
# 13056  http://www.ikea.lt/en/products/children-s-room...      instock
# 13062  http://www.ikea.lt/en/products/children-s-room...      instock
# 13048  http://www.ikea.lt/en/products/children-s-room...      instock
# 13092  http://www.ikea.lt/en/products/children-s-room...      instock
# 5069   http://www.ikea.lt/en/products/living-room/dec...      instock
# 5209   http://www.ikea.lt/en/products/living-room/dec...      instock
# 5040   http://www.ikea.lt/en/products/living-room/dec...      instock
#
#               metatype        type             subtype  packages  length  \
# 13056  children-s-room        baby     changing-tables       3.0    96.0
# 13062  children-s-room        baby     changing-tables       3.0    96.0
# 13048  children-s-room        baby                cots       3.0   123.0
# 13092  children-s-room        baby                cots       3.0   123.0
# 5069       living-room  decoration  holiday-decoration       1.0    24.0
# 5209       living-room  decoration  holiday-decoration       1.0    62.0
# 5040       living-room  decoration  holiday-decoration       1.0    32.0
#
#        width  height  weight gross   price  similarity
# 13056   84.0     6.0         25.58  199.00    0.160059
# 13062   84.0     6.0         25.58  199.00    0.160059
# 13048   57.0     6.0         20.50  249.00    0.160059
# 13092   57.0     6.0         20.50  249.00    0.160059
# 5069    24.0    11.0          0.40    9.99    0.158635
# 5209    16.0    16.0          0.75   12.99    0.158635
# 5040    26.0     7.0          0.45   12.99    0.158635

# %%
# Will only return items with similarity for other attributes greater than 0.5
res,_ = most_similar(1,df,embeddings,limit=7,unique=True,threshold=-0.5,append=True)
res
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_13676/2236647437.py in <module>
#       1 # Will only return items with similarity for other attributes greater than 0.5
# ----> 2 res,_ = most_similar(1,df,embeddings,limit=7,unique=True,threshold=-0.5,append=True)
#       3 res
#
# ~\AppData\Local\Temp/ipykernel_13676/4194752284.py in most_similar(row, df, embeddings, limit, unique, threshold, categorical_weight, numeric_weight, reverse, append)
#      52
#      53
# ---> 54     relevant = np.ones(len(df)).astype("bool")
#      55     if threshold != 0:
#      56         col_categorical =  [0,*list(range(2,8))]
#
# NameError: name 'np' is not defined

# %%
# Will only return items with similarity for other attributes less than 0.5
# Will also search for the LEAST similar items
res,_ = most_similar(1,df,embeddings,limit=7,unique=True,threshold=-0.5,reverse=True,append=True)
res
# Out:
#                  title                                        description  \
# 5938        LYDERSHOLM  The rug is perfect for outdoor use because it’...
# 6029        LYDERSHOLM  The rug is perfect for outdoor use because it’...
# 5967        LYDERSHOLM  The colour and weave create a natural look.\nT...
# 12183         FLODALEN  The towel is made from yarn that has been tigh...
# 15110  JANINGE/VANGSTA  Extendable dining table with 1 extra leaf seat...
# 7485         SONGESAND  You save space with a mirror door, since you d...
# 6051         SONGESAND  Adjustable bed sides allow you to use mattress...
#
#                                                      url  availability  \
# 5938   http://www.ikea.lt/en/products/living-room/hom...       instock
# 6029   http://www.ikea.lt/en/products/living-room/hom...  out of stock
# 5967   http://www.ikea.lt/en/products/living-room/hom...       instock
# 12183  http://www.ikea.lt/en/products/bathroom/towels...  out of stock
# 15110  http://www.ikea.lt/en/products/dining-room/din...       instock
# 7485   http://www.ikea.lt/en/products/bedroom/solitai...       instock
# 6051   http://www.ikea.lt/en/products/beds-mattresses...       instock
#
#               metatype                  type                 subtype  \
# 5938       living-room  home-furnishing-rugs                    rugs
# 6029       living-room  home-furnishing-rugs                    rugs
# 5967       living-room  home-furnishing-rugs  small-rugs-and-runners
# 12183         bathroom       towels-bathmats                  towels
# 15110      dining-room         dining-tables                  tables
# 7485           bedroom   solitaire-wardrobes     solitaire-wardrobes
# 6051   beds-mattresses                  beds              bed-frames
#
#        packages  length  width  height  weight gross   price  similarity
# 5938        1.0   164.0    NaN     NaN          4.46   59.99   -0.141231
# 6029        1.0   135.0    NaN     NaN          3.10   39.99   -0.141231
# 5967        1.0    81.0    NaN     NaN          1.48   19.99   -0.141231
# 12183       1.0    31.0   16.0     6.0          0.06    2.49   -0.127384
# 15110       2.0    77.0   52.0    47.0          4.80  139.97   -0.121360
# 7485        4.0   186.0   54.0     4.0         21.50  179.00   -0.120354
# 6051        2.0   206.0   28.0     9.0         24.20  109.00   -0.120354

# %%
def find_duplicates(df, row = None, by_columns = None, drop = False):
    """Find duplicate items 

    Parameters
    ----------
    df : DataFrame
        DataFrame to find duplicated in.
    row : int or named Series or DataFrame, default None
        The row to find duplicates for.
        If None will check for duplicates for any row.
        If given a DataFrame the first row will be selected.
        If given an int the df will be indexed using it as a label.
    by_column: list, default None
        The columns names or integers specifying the columns locations
        required to match to be considered duplicate, None for all columns.
    drop: boolean
        Whether to drop the duplicated rows in the original data.

    Returns
    -------
    DataFrame
        DataFrame with only the duplicates for the specified row.
    """
    
    if by_columns is None:
        by_columns = df.columns
    if row is None:
        duplicate_rows = df[df.loc[:,by_columns].duplicated()]
    else:
        if isinstance(row,int):
            row = df.loc[row,:]
        elif isinstance(row,pd.DataFrame):
            row = row.iloc[0,:]
        duplicate = pd.DataFrame(row[by_columns] == df.loc[:,by_columns]).all(axis=1)
        # preventing row from being a duplicate of itself
        duplicate.loc[row.name] = False
        duplicate_rows = df.loc[duplicate] 
    if drop:
        df.drop(duplicate_rows.index, inplace = True)
    return duplicate_rows

# %%
find_duplicates(df,22) # There doesn't seem to be any duplicates

find_duplicates(df,22,["title","description"]) # finds duplicates when searching for duplicates using only specified columns
# Out:
#        title                                        description  \
# 24  STARTTID  The backpack has a handy outer compartment whe...
#
#                                                   url availability metatype  \
# 24  http://www.ikea.lt/en/products/hallway/bags-an...      instock  hallway
#
#                            type                      subtype  packages  \
# 24  bags-and-travel-accessories  bags-and-travel-accessories       1.0
#
#     length  width  height  weight gross  price
# 24    38.0   33.0     3.0          0.29   6.99

# %%
find_duplicates(df,200,["title","description"],drop=True) # duplicates are found be they are deleted
# Out:
#         title                                        description  \
# 189    VIMUND  This ergonomic junior chair has a flexible bac...
# 609    VIMUND  This ergonomic junior chair has a flexible bac...
# 627    VIMUND  This ergonomic junior chair has a flexible bac...
# 13596  VIMUND  This ergonomic junior chair has a flexible bac...
# 13597  VIMUND  This ergonomic junior chair has a flexible bac...
#
#                                                      url availability  \
# 189    http://www.ikea.lt/en/products/children-s-room...      instock
# 609    http://www.ikea.lt/en/products/children-s-room...      instock
# 627    http://www.ikea.lt/en/products/children-s-room...      instock
# 13596  http://www.ikea.lt/en/products/children-s-room...      instock
# 13597  http://www.ikea.lt/en/products/children-s-room...      instock
#
#               metatype           type             subtype  packages  length  \
# 189    children-s-room  for-teenagers  home-office-chairs       1.0    57.0
# 609    children-s-room  for-teenagers  home-office-chairs       1.0    57.0
# 627    children-s-room  for-teenagers  home-office-chairs       1.0    57.0
# 13596  children-s-room  for-teenagers  home-office-chairs       1.0    57.0
# 13597  children-s-room  for-teenagers  home-office-chairs       1.0    57.0
#
#        width  height  weight gross  price
# 189     45.0    16.0         10.92  49.99
# 609     45.0    16.0         10.92  49.99
# 627     45.0    16.0         10.92  49.99
# 13596   45.0    16.0         10.92  49.99
# 13597   45.0    16.0         10.92  49.99

# %%
find_duplicates(df,200,["title","description"]) # No duplicates are found this time
# Out:
# Empty DataFrame
# Columns: [title, description, url, availability, metatype, type, subtype, packages, length, width, height, weight gross, price]
# Index: []

# %%
# Returning all items that have exact same measurements as some other item
find_duplicates(df,None,["length","width","height"])
# Out:
#                        title  \
# 16                  VÄRLDENS
# 21                    SKYNKE
# 22                  STARTTID
# 24                  STARTTID
# 26               KARISMATISK
# ...                      ...
# 21581               KNARDRUP
# 21582              AVSKILDRA
# 21583               LANGSTED
# 21584              SVÄRDBORG
# 21585  PERSISK KELIM GASHGAI
#
#                                              description  \
# 16     Separate, padded compartment with a zipper tha...
# 21     Easy to keep on hand since it folds very small...
# 22     The backpack has a handy outer compartment whe...
# 24     The backpack has a handy outer compartment whe...
# 26     You can do something good for the environment ...
# ...                                                  ...
# 21581  A timeless design with a sheen effect.\nThe so...
# 21582  The beauty is in the uniqueness - this rug is ...
# 21583  The cut edges makes it easy to join several ru...
# 21584  The beauty is in the uniqueness - this rug is ...
# 21585  The rug has the same pattern on both sides, so...
#
#                                                      url  availability  \
# 16     http://www.ikea.lt/en/products/hallway/bags-an...       instock
# 21     http://www.ikea.lt/en/products/hallway/bags-an...       instock
# 22     http://www.ikea.lt/en/products/hallway/bags-an...       instock
# 24     http://www.ikea.lt/en/products/hallway/bags-an...       instock
# 26     http://www.ikea.lt/en/products/hallway/bags-an...       instock
# ...                                                  ...           ...
# 21581  http://www.ikea.lt/en/products/living-room/hom...  out of stock
# 21582  http://www.ikea.lt/en/products/living-room/hom...  out of stock
# 21583  http://www.ikea.lt/en/products/living-room/hom...  out of stock
# 21584  http://www.ikea.lt/en/products/living-room/hom...  out of stock
# 21585  http://www.ikea.lt/en/products/living-room/hom...  out of stock
#
#           metatype                         type                      subtype  \
# 16         hallway  bags-and-travel-accessories  bags-and-travel-accessories
# 21         hallway  bags-and-travel-accessories  bags-and-travel-accessories
# 22         hallway  bags-and-travel-accessories  bags-and-travel-accessories
# 24         hallway  bags-and-travel-accessories  bags-and-travel-accessories
# 26         hallway  bags-and-travel-accessories  bags-and-travel-accessories
# ...            ...                          ...                          ...
# 21581  living-room         home-furnishing-rugs                         rugs
# 21582  living-room         home-furnishing-rugs                         rugs
# 21583  living-room         home-furnishing-rugs       small-rugs-and-runners
# 21584  living-room         home-furnishing-rugs                         rugs
# 21585  living-room         home-furnishing-rugs                oriental-rugs
#
#        packages  length  width  height  weight gross   price
# 16          1.0    54.0   42.0     3.0          0.70   39.99
# 21          1.0    11.0   11.0     1.0          0.04    0.99
# 22          1.0    38.0   33.0     3.0          0.29    6.99
# 24          1.0    38.0   33.0     3.0          0.29    6.99
# 26          1.0    11.0   11.0     1.0          0.04    0.99
# ...         ...     ...    ...     ...           ...     ...
# 21581       1.0   202.0    NaN     NaN         10.85  179.00
# 21582       1.0   174.0    NaN     NaN         18.30  279.00
# 21583       1.0    80.0   80.0    15.0          1.40    9.99
# 21584       1.0   138.0    NaN     NaN         11.54  199.00
# 21585       1.0   300.0   80.0     1.0          4.40  229.00
#
# [17596 rows x 13 columns]

# %%
def showcase(row,df,embeddings = None,limit=5,unique = True,
                 return_middle = True, append = False):
    
    """Find the most and the least similar items.
    
    Compares the sentence embeddings for the descriptions of the items
    using cosine similarity and returns items that are the most, the least similar 
    and possibly in the middle by similarity.

    Parameters
    ----------
    row : int or named Series or DataFrame
        The row to find the most similar items for.
        If given a DataFrame the first row will be selected.
        If given an int the df will be indexed using it as a label.
    df : DataFrame
        DataFrame to find the most similar items in.
    embeddings: array_like, Default None
        Sentence embeddings to compare the description of a given row against using cosine similarity.
    limit: int, Default 5
        The number of items to return.
    unique: boolean, Default True
        Whether to return only one item most with the same description. 
    return_middle: boolean, Default True
    append: boolean, Default False
        Whether to add the cosine similariy as a column of the returned DataFrame

    Returns
    -------
    DataFrame:
        DataFrame with the items most similar to the given row.
    Series:
        Series with the similarity scores for each row of the returned DataFrame.
    """
    
    if embeddings is None or len(embeddings) != len(df):
        raise ValueError("Compatible sentence embeddings not found!\nYou probably deleted rows from the\
        data frame since the last time you ran this\nCreate the embeddings again")
    
    if isinstance(row,int):
        row = df.loc[row,:]
    elif isinstance(row,pd.DataFrame):
        row = row.iloc[0,:]


    results=cosine(embeddings,model(np.array(row[1]).reshape(1)))
    results=pd.Series(results[:,0],index=df.index)
    results=results[df["description"]!=row[1]]
    
    if unique:
        results=results[~df["description"].duplicated()]
    
    results=results.sort_values(ascending=False)
    length = len(results) - 1
    middle = length//2 
    
    if not return_middle:
        rows = [*range(0,limit),*range(length-limit,length)]       
    else:
        rows = [*range(0,limit),*range(middle,middle+limit),*range(length-limit,length)]    
  
    results = results.iloc[rows]
    results_df = df.loc[results.index]   
    
    if append:
        results_df = results_df.copy()
        results_df["similarity"] = results
        
    return results_df, results

# %%
df.iloc[5000,1]
# Out:
# 'The included collage template and coordinated motifs make it easy to create your own personal wall collage.\nMotif created by Odilon Redon, Albrecht Dürer, Theodor Severin Kittelsen, Théophile Steinlen and Paul Cézanne.\nThe motifs are in place and the pictures are ready to hang.\nIf you want some variation, you can easily change motif in the frame.\nYou can split the wall collage template into smaller collages and display your art in different ways.\nHolds 8 pictures so you can create your own personal collage.\nFront protection in plastic makes the frame safer to use.\nThe motifs have a common theme so you can easily create a coherent collage.\nYou can personalise your home with artwork that expresses your style.\n'

# %%
# Returning the most and the least similar items at the same time
rez,_ = showcase(5000,df,embeddings,5,return_middle=True,append=True)
rez
# Out:
#              title                                        description  \
# 9537   SKOGSFRÄKEN  A high, easy-care pillow with a cotton and lyo...
# 9538   SKOGSFRÄKEN  A low, easy-care pillow with a cotton and lyoc...
# 4375        ISJAKT  The uplighter spreads a pleasant light that il...
# 18183        JOSEF  The cabinet has two adjustable shelves and the...
# 15347      KRUSTAD  Made of feldspar porcelain, which makes the bo...
# 906         KALLAX  The practical inserts hide things and help mai...
# 957         KALLAX  Easy to assemble.\nThe insert looks nice in a ...
# 876         KALLAX  An easy-to-place shelving unit for storing and...
# 1330        KALLAX  An easy-to-place shelving unit for storing and...
# 881         KALLAX  The practical inserts hide things and help mai...
# 14759     SAKARIAS  Dine in style and comfort. This upholstered ch...
# 14933     SAKARIAS  Dine in style and comfort. This upholstered ch...
# 14863     SAKARIAS  Extra covers to alternate with mean it's easy ...
# 14934     SAKARIAS  This cover is made of the natural based fabric...
# 14818     SAKARIAS  You don’t have to worry about spills since the...
#
#                                                      url  availability  \
# 9537   http://www.ikea.lt/en/products/bedroom/bedding...       instock
# 9538   http://www.ikea.lt/en/products/bedroom/bedding...       instock
# 4375   http://www.ikea.lt/en/products/living-room/liv...  out of stock
# 18183  http://www.ikea.lt/en/products/outdoor/outdoor...       instock
# 15347  http://www.ikea.lt/en/products/kitchen/servewa...       instock
# 906    http://www.ikea.lt/en/products/living-room/she...       instock
# 957    http://www.ikea.lt/en/products/living-room/she...       instock
# 876    http://www.ikea.lt/en/products/living-room/she...       instock
# 1330   http://www.ikea.lt/en/products/living-room/she...       instock
# 881    http://www.ikea.lt/en/products/living-room/she...       instock
# 14759  http://www.ikea.lt/en/products/dining-room/din...       instock
# 14933  http://www.ikea.lt/en/products/dining-room/din...  out of stock
# 14863  http://www.ikea.lt/en/products/dining-room/din...       instock
# 14934  http://www.ikea.lt/en/products/dining-room/din...  out of stock
# 14818  http://www.ikea.lt/en/products/dining-room/din...       instock
#
#           metatype                    type                 subtype  packages  \
# 9537       bedroom                 bedding                 pillows       1.0
# 9538       bedroom                 bedding                 pillows       1.0
# 4375   living-room    living-room-lighting             floor-lamps       1.0
# 18183      outdoor      outdoor-organising      outdoor-organising       1.0
# 15347      kitchen               serveware  dinnerware-and-serving       1.0
# 906    living-room  shelving-units-systems     open-shelving-units       2.0
# 957    living-room  shelving-units-systems     open-shelving-units       1.0
# 876    living-room  shelving-units-systems     open-shelving-units       2.0
# 1330   living-room  shelving-units-systems     open-shelving-units       2.0
# 881    living-room  shelving-units-systems     open-shelving-units       2.0
# 14759  dining-room          dining-seating      chairs-and-benches       1.0
# 14933  dining-room          dining-seating      chairs-and-benches       1.0
# 14863  dining-room          dining-seating                  stools       1.0
# 14934  dining-room          dining-seating      chairs-and-benches       1.0
# 14818  dining-room          dining-seating                  stools       1.0
#
#        length  width  height  weight gross   price  similarity
# 9537     48.0    NaN     NaN          0.87    9.99    0.189384
# 9538     48.0    NaN     NaN          0.68    8.99    0.189384
# 4375     93.0   25.0     7.0          6.70   59.99    0.181810
# 18183    87.0   38.0    10.0         11.50   39.99    0.169603
# 15347     NaN    NaN     7.0          0.33    2.99    0.166961
# 906      73.0   34.0     4.0          4.64  151.00    0.022454
# 957      73.0   34.0     4.0          4.65   19.00    0.022454
# 876      46.0   34.0     3.0          2.55   73.99    0.022454
# 1330     45.0   34.0     3.0          2.35  139.99    0.022454
# 881      70.0   34.0     1.0          0.90   66.97    0.022454
# 14759   114.0   69.0    28.0         14.20   99.00   -0.124764
# 14933    35.0   23.0     8.0          0.96  129.00   -0.124764
# 14863    36.0   19.0     1.0          0.17    5.00   -0.124764
# 14934    35.0   23.0     8.0          0.96   30.00   -0.124764
# 14818    37.0   19.0     1.0          0.23   10.00   -0.124764

# %%
# Misc

# %%
import csv

x = pd.DataFrame(df["subtype"].unique())
x = x[x.notna()]
x[1]=x[0].str.replace("-"," ")
x.to_csv("entity.csv",index=False,header=False,quoting = csv.QUOTE_ALL)

# %%
regex = re.compile(".+/")
regex.findall(df["url"][~df["subtype"].duplicated()].iloc[99])[0]

x = df[~df["subtype"].duplicated()]_unique.copy()                      
x["url"] = x["url"].str.extract("(.+/)")
x = x[["url","subtype"]]

dictionary = {}
for i in range(len(x)):
    dictionary[x.iloc[i,1]] = x.iloc[i,0]

# %%
def search_string(string,df,append = True):
    string_embedding = model(tf.convert_to_tensor([string]))
    results=cosine(string_embedding,embeddings)[0]
    results=pd.Series(results,index=df.index)     
    results.sort_values(ascending=False,inplace=True)

    if append:
        results_df = df.loc[results.index].copy()
        results_df["similarity"] = results
    return results_df, results

# %%
search_string("artificial plant",df)[0]
# Out:
#            title                                        description  \
# 19120      FEJKA  Lifelike artificial plant that remain just as ...
# 4916       FEJKA  Lifelike artificial plant that remain just as ...
# 10898      FEJKA  Lifelike artificial plant that remain just as ...
# 12627      FEJKA  Lifelike artificial plant that remain just as ...
# 16691      FEJKA  Lifelike artificial plant that remain just as ...
# ...          ...                                                ...
# 2552      GALLRA  Protects the table top surface and reduces noi...
# 2550      SLUTEN  Protects the table top surface and reduces noi...
# 2549   SMAKSINNE  Protects the table top surface and reduces noi...
# 2545       PANNÅ  Protects the table top surface and reduces noi...
# 2557     SNOBBIG  Protects the table top surface and reduces noi...
#
#                                                      url  availability  \
# 19120  http://www.ikea.lt/en/products/living-room/dec...       instock
# 4916   http://www.ikea.lt/en/products/living-room/dec...       instock
# 10898  http://www.ikea.lt/en/products/living-room/dec...  out of stock
# 12627  http://www.ikea.lt/en/products/living-room/dec...       instock
# 16691  http://www.ikea.lt/en/products/living-room/dec...  out of stock
# ...                                                  ...           ...
# 2552   http://www.ikea.lt/en/products/kitchen/servewa...       instock
# 2550   http://www.ikea.lt/en/products/kitchen/servewa...       instock
# 2549   http://www.ikea.lt/en/products/kitchen/servewa...       instock
# 2545   http://www.ikea.lt/en/products/kitchen/servewa...       instock
# 2557   http://www.ikea.lt/en/products/kitchen/servewa...       instock
#
#           metatype        type            subtype  packages  length  width  \
# 19120  living-room  decoration  artificial-plants       1.0    55.0    NaN
# 4916   living-room  decoration  artificial-plants       1.0    55.0    NaN
# 10898  living-room  decoration  artificial-plants       1.0    63.0    NaN
# 12627  living-room  decoration  artificial-plants       1.0    21.0    NaN
# 16691  living-room  decoration  artificial-plants       1.0    63.0    NaN
# ...            ...         ...                ...       ...     ...    ...
# 2552       kitchen   serveware        table-linen       1.0    45.0   33.0
# 2550       kitchen   serveware        table-linen       1.0     0.0    NaN
# 2549       kitchen   serveware        table-linen       1.0    37.0   37.0
# 2545       kitchen   serveware        table-linen       1.0    37.0   37.0
# 2557       kitchen   serveware        table-linen       1.0    45.0   33.0
#
#        height  weight gross  price  similarity
# 19120     NaN          0.33   4.99    0.556706
# 4916      NaN          0.33   4.99    0.556706
# 10898     NaN          0.63  19.99    0.556706
# 12627     NaN          0.20   2.99    0.556706
# 16691     NaN          0.63  19.99    0.556706
# ...       ...           ...    ...         ...
# 2552      0.0          0.06   1.49   -0.169614
# 2550      NaN          0.05   1.99   -0.169614
# 2549      0.0          0.07   1.49   -0.169614
# 2545      0.0          0.06   1.99   -0.169614
# 2557      0.0          0.06   3.49   -0.169614
#
# [21586 rows x 14 columns]
